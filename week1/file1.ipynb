# %% [markdown]
# this is my fist file in my LLM jouney

# %%
# importing required libraries

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you. I’m here to chat, answer questions, help with tasks, and more. \n\nA few things I can do:\n- Explain topics and answer questions in simple terms\n- Help with writing, editing, and brainstorming\n- Debug code or explain programming concepts\n- Plan trips, organize schedules, or brainstorm ideas\n- Translate or practice a language\n- Summarize articles or documents\n\nWhat would you like to do today? If you’re not sure, you can try:\n- “Explain photosynthesis in simple terms.”\n- “Help me brainstorm birthday gift ideas.”\n- “Can you write a short story about a robot and a cat?”\n- “Plan a weekend trip to a nearby city.”'

# %%
# Let's try out this utility

vk = fetch_website_contents("https://www.instagram.com/vaibhau.exe")
print(vk)
# Out:
# Instagram

# %%
scribber = fetch_website_contents("https://www.scribbr.com/statistics/")
print(scribber)
# Out:
# The Beginner's Guide to Statistical Analysis | 5 Steps & Examples
#
# FAQ
# About us
# Our editors
# Team
# Jobs
# Contact
# My account
# Orders
# Upload
# Account details
# Logout
# My account
# Overview
# Availability
# Information package
# Account details
# Logout
# Admin
# Log in
# Search
# Plagiarism
# Plagiarism Checker
# Catch accidental plagiarism, using similar software as universities.
# AI Detector
# Detect AI-generated content like ChatGPT.
# Proofreading
# Human Proofreading
# Professional editing in just 3 hours.
# AI-Proofreading
# Improve your entire paper within 5 minutes.
# Grammar Checker
# Check small text fragments to check for errors.
# Our experts can help with your:
# Paper
# Thesis
# Dissertation
# College admission essay
# APA editing
# Personal statement
# Academic writing
# Paper Formatting
# Citing
# Citation Generator
# Generate accurate citations, verified by experts.
# Improve your citations
# Use human experts or AI to perfect your citations.
# Generate these styles:
# APA
# MLA
# Chicago style
# AMA
# IEEE
# ACS
# AI Writing
# Paraphrasing Tool
# Rewrite texts in your own words.
# Grammar Checker
# Check small text fragments to check for errors.
# Summarizer
# Extract key points and read more in less time.
# AI Detector
# Detect AI-generated content like ChatGPT.
# AI Proofreader
# Improve your entire paper within 5 minutes.
# AI Humanizer
# Make AI writing sound natural and human.
# Learn
# Plagiarism
# Proofreading
# Citing
# AI Writing
# Learn
# Nederlands
# English
# Deutsch
# Français
# Italiano
# Español
# Svenska
# Dansk
# Suomi
# Norwegian Bokmål
# FAQ
# About us
# My account
# My account
# Admin
# Log in
# Back
# Plagiarism Checker
# AI Detector
# Back
# Human Proofreading
# AI-Proofreading
# Grammar Checker
# Our experts can help with your:
# Paper
# Thesis
# Dissertation
# College admission essay
# APA editing
# Personal statement
# Academic writing
# Paper Formatting
# Back
# Citation Generator
# Improve your citations
# Generate these styles:
# APA
# MLA
# Chicago style
# AMA
# IEEE
# ACS
# Back
# Paraphrasing Tool
# Grammar Checker
# Summarizer
# AI Detector
# AI Proofreader
# AI Humanizer
# Back
# Our editors
# Team
# Jobs
# Contact
# Back
# Orders
# Upload
# Account detai
